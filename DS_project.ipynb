# %%
import pandas as pd
df = pd.read_csv("shopping ca2.csv")
df.head()
# Out:
#   ENTER YOUR NAME WHAT PRODUCT WAS PURCHASED?  \
# 0          Aasiya                    Lipstick
# 1            Ashu                       Shoes
# 2        Shrusthi                       Shoes
# 3          Sakshi                Mobile Phone
# 4        Priyanka             Washing machine
#
#   WHICH CATEGORY DOES THIS PRODUCT BELONG TO? HOW MANY UNITS WERE PURCHASED?  \
# 0                                      BEAUTY                              2
# 1                                    FOOTWEAR                              1
# 2                                    FOOTWEAR                              1
# 3                                 ELECTRONICS                              1
# 4                                 ELECTRONICS                              1
#
#   WHAT IS THE PRICE PER UNIT? (IN RS)  \
# 0                                 200
# 1                                2000
# 2                                2000
# 3                               20000
# ...

# %%
print("\nFirst 5 Records:")
print(df.head())

print("\nLast 5 Records:")
print(df.tail())
# Out:
# First 5 Records:
#   ENTER YOUR NAME WHAT PRODUCT WAS PURCHASED?  \
# 0          Aasiya                    Lipstick
# 1            Ashu                       Shoes
# 2        Shrusthi                       Shoes
# 3          Sakshi                Mobile Phone
# 4        Priyanka             Washing machine
#
#   WHICH CATEGORY DOES THIS PRODUCT BELONG TO? HOW MANY UNITS WERE PURCHASED?  \
# 0                                      BEAUTY                              2
# 1                                    FOOTWEAR                              1
# 2                                    FOOTWEAR                              1
# 3                                 ELECTRONICS                              1
# 4                                 ELECTRONICS                              1
#
#   WHAT IS THE PRICE PER UNIT? (IN RS)  \
# 0                                 200
# 1                                2000
# 2                                2000
# 3                               20000
# ...

# %%
print("\nShape of Dataset:")
print(df.shape)
print("\nColumn Names:")
print(df.columns)
print("\nData Types:")
print(df.dtypes)
# Out:
# Shape of Dataset:
# (102, 13)
#
# Column Names:
# Index(['ENTER YOUR NAME', 'WHAT PRODUCT WAS PURCHASED?',
#        'WHICH CATEGORY DOES THIS PRODUCT BELONG TO?',
#        'HOW MANY UNITS WERE PURCHASED?', 'WHAT IS THE PRICE PER UNIT? (IN RS)',
#        'WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?',
#        'WHAT IS THE TOTAL PRICE AFTER DISCOUNT?', 'WHAT WAS THE ORDER DATE?',
#        'WHAT PAYMENT METHOD WAS USED?',
#        'WHAT IS THE CURRENT STATUS OF THE ORDER?',
#        'TO WHICH CITY WAS THE ORDER DELIVERED?',
#        'WHICH REGION DOES THE CITY BELONG TO?', 'order placed time'],
#       dtype='object')
#
# Data Types:
# ENTER YOUR NAME                                   object
# WHAT PRODUCT WAS PURCHASED?                       object
# WHICH CATEGORY DOES THIS PRODUCT BELONG TO?       object
# HOW MANY UNITS WERE PURCHASED?                    object
# WHAT IS THE PRICE PER UNIT? (IN RS)               object
# WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?     int64
# ...

# %%
df["WHAT WAS THE ORDER DATE?"] = pd.to_datetime(
    df["WHAT WAS THE ORDER DATE?"], errors="coerce")
df["order placed time"] = pd.to_datetime(
    df["order placed time"], errors="coerce")
print("\nConverted Order Date and Order Placed Time to datetime")
df.tail()
# Out:
# Converted Order Date and Order Placed Time to datetime
# /tmp/ipython-input-2929257632.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["order placed time"] = pd.to_datetime(
#     ENTER YOUR NAME WHAT PRODUCT WAS PURCHASED?  \
# 97           Bhavya                           N
# 98          Anandhi                           N
# 99           Aarohi                           N
# 100           Sania             Wired earphones
# 101         Deepika                    Cleanser
#
#     WHICH CATEGORY DOES THIS PRODUCT BELONG TO?  \
# 97                               HOME & KITCHEN
# 98                                    WEARABLES
# 99                               HOME & KITCHEN
# 100                                 ELECTRONICS
# 101                                      BEAUTY
#
# ...

# %%
df["HOW MANY UNITS WERE PURCHASED?"] = df["HOW MANY UNITS WERE PURCHASED?"].replace(
    ["MORE THAN 4", "More than 4"], 5)
df["HOW MANY UNITS WERE PURCHASED?"] = pd.to_numeric(
    df["HOW MANY UNITS WERE PURCHASED?"], errors="coerce")
print("\nHandled inconsistent values in Units Purchased",df)
# Out:
# Handled inconsistent values in Units Purchased     ENTER YOUR NAME WHAT PRODUCT WAS PURCHASED?  \
# 0            Aasiya                    Lipstick
# 1              Ashu                       Shoes
# 2          Shrusthi                       Shoes
# 3            Sakshi                Mobile Phone
# 4          Priyanka             Washing machine
# ..              ...                         ...
# 97           Bhavya                           N
# 98          Anandhi                           N
# 99           Aarohi                           N
# 100           Sania             Wired earphones
# 101         Deepika                    Cleanser
#
#     WHICH CATEGORY DOES THIS PRODUCT BELONG TO?  \
# 0                                        BEAUTY
# 1                                      FOOTWEAR
# 2                                      FOOTWEAR
# 3                                   ELECTRONICS
# 4                                   ELECTRONICS
# ...

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", ""))
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce")
print("\nRemoved commas and converted Total Price After Discount to numeric")
# Out:
# Removed commas and converted Total Price After Discount to numeric

# %%
before = df.shape[0]
df.drop_duplicates(inplace=True)
after = df.shape[0]
print("\nDuplicate Rows Removed:", before - after)
# Out:
# Duplicate Rows Removed: 0

# %%
print("\nCleaned Dataset Preview:")
print(df.head())
# Out:
# Cleaned Dataset Preview:
#   ENTER YOUR NAME WHAT PRODUCT WAS PURCHASED?  \
# 0          Aasiya                    Lipstick
# 1            Ashu                       Shoes
# 2        Shrusthi                       Shoes
# 3          Sakshi                Mobile Phone
# 4        Priyanka             Washing machine
#
#   WHICH CATEGORY DOES THIS PRODUCT BELONG TO?  HOW MANY UNITS WERE PURCHASED?  \
# 0                                      BEAUTY                               2
# 1                                    FOOTWEAR                               1
# 2                                    FOOTWEAR                               1
# 3                                 ELECTRONICS                               1
# 4                                 ELECTRONICS                               1
#
#   WHAT IS THE PRICE PER UNIT? (IN RS)  \
# 0                                 200
# 1                                2000
# 2                                2000
# ...

# %%
total_orders = df.shape[0]
print("Total number of orders placed:", total_orders)
# Out:
# Total number of orders placed: 102

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
    .astype(float))
total_revenue = df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
print("Total revenue after discount:", total_revenue)
# Out:
# Total revenue after discount: 488793.0

# %%
df["WHAT IS THE PRICE PER UNIT? (IN RS)"] = (
    df["WHAT IS THE PRICE PER UNIT? (IN RS)"]
    .astype(str)
    .str.replace(",", "")
    .astype(float))
avg_price_per_unit = df["WHAT IS THE PRICE PER UNIT? (IN RS)"].mean()
print("Average price per unit:", avg_price_per_unit)
# Out:
# Average price per unit: 5921.901960784314

# %%
avg_discount = df["WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?"].mean()
print("Average discount percentage:", avg_discount)
# Out:
# Average discount percentage: 24.676470588235293

# %%
min_order_value = df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].min()
max_order_value = df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].max()
print("Minimum order value:", min_order_value)
print("Maximum order value:", max_order_value)
# Out:
# Minimum order value: 47.0
# Maximum order value: 61500.0

# %%
orders_per_category = df["WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"].value_counts()
print("\nNumber of orders per product category:")
print(orders_per_category)
# Out:
# Number of orders per product category:
# WHICH CATEGORY DOES THIS PRODUCT BELONG TO?
# ELECTRONICS       23
# CLOTHING          20
# BEAUTY            19
# ACCESSORIES       10
# FOOTWEAR           9
# HOME & KITCHEN     9
# WEARABLES          8
# OTHERS             4
# Name: count, dtype: int64

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
import matplotlib.pyplot as plt
category_counts = df["WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"].value_counts()
plt.figure()
plt.bar(category_counts.index, category_counts.values,color='r')
plt.title("Number of Orders per Product Category")
plt.xlabel("Product Category")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
plt.hist(df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].dropna(), bins=10)
plt.title("Histogram of Total Price After Discount")
plt.xlabel("Total Price After Discount")
plt.ylabel("Frequency")
plt.show()

# %%
payment_counts = df["WHAT PAYMENT METHOD WAS USED?"].value_counts()
plt.figure()
plt.bar(payment_counts.index, payment_counts.values,color='green')
plt.title("Payment Methods Used")
plt.xlabel("Payment Method")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
status_counts = df["WHAT IS THE CURRENT STATUS OF THE ORDER?"].value_counts()
plt.figure()
plt.pie(status_counts.values, labels=status_counts.index, autopct="%1.1f%%")
plt.title("Order Status Distribution")
plt.show()

# %%
city_counts = df["TO WHICH CITY WAS THE ORDER DELIVERED?"].value_counts()
plt.figure()
plt.bar(city_counts.index, city_counts.values)
plt.title("City-wise Order Count")
plt.xlabel("City")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
df["HOW MANY UNITS WERE PURCHASED?"] = df["HOW MANY UNITS WERE PURCHASED?"].replace(
    ["MORE THAN 4", "More than 4"], 5
)
df["HOW MANY UNITS WERE PURCHASED?"] = pd.to_numeric(
    df["HOW MANY UNITS WERE PURCHASED?"], errors="coerce"
)

# %%
plt.figure()
df.boxplot(
    column="WHAT IS THE TOTAL PRICE AFTER DISCOUNT?",
    by="WHICH CATEGORY DOES THIS PRODUCT BELONG TO?",
    rot=45)
plt.title("Total Price After Discount vs Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Price After Discount")
plt.show()

# %%
avg_discount = df.groupby(
    "WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"
)["WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?"].mean()
plt.figure()
plt.bar(avg_discount.index, avg_discount.values)
plt.title("Average Discount Percentage by Category")
plt.xlabel("Product Category")
plt.ylabel("Average Discount (%)")
plt.xticks(rotation=45)
plt.show()

# %%
payment_status = pd.crosstab(
    df["WHAT PAYMENT METHOD WAS USED?"],
    df["WHAT IS THE CURRENT STATUS OF THE ORDER?"])
payment_status.plot(kind="bar")
plt.title("Payment Method vs Order Status")
plt.xlabel("Payment Method")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
plt.scatter(
    df["HOW MANY UNITS WERE PURCHASED?"],
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
)
plt.title("Units Purchased vs Total Price After Discount")
plt.xlabel("Units Purchased")
plt.ylabel("Total Price After Discount")
plt.show()

# %%
region_status = pd.crosstab(
    df["WHICH REGION DOES THE CITY BELONG TO?"],
    df["WHAT IS THE CURRENT STATUS OF THE ORDER?"])
region_status.plot(kind="bar")
plt.title("Region vs Order Status")
plt.xlabel("Region")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
df["WHAT WAS THE ORDER DATE?"] = pd.to_datetime(
    df["WHAT WAS THE ORDER DATE?"], errors="coerce"
)

# Convert Order Placed Time to datetime
df["order placed time"] = pd.to_datetime(
    df["order placed time"], errors="coerce"
)

# Clean Total Price After Discount
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
orders_per_day = df["WHAT WAS THE ORDER DATE?"].value_counts().sort_index()
plt.figure()
plt.plot(orders_per_day.index, orders_per_day.values)
plt.title("Number of Orders Placed Per Day")
plt.xlabel("Order Date")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
daily_revenue = df.groupby("WHAT WAS THE ORDER DATE?")[
    "WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"
].sum()
plt.figure()
plt.plot(daily_revenue.index, daily_revenue.values)
plt.title("Daily Revenue Trend")
plt.xlabel("Order Date")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
df["order_hour"] = df["order placed time"].dt.hour
peak_hour = df["order_hour"].value_counts().idxmax()

print("Peak order placement hour:", peak_hour)
# Out:
# Peak order placement hour: 9

# %%
morning_orders = df[
    (df["order_hour"] >= 6) & (df["order_hour"] < 10)
].shape[0]
late_morning_orders = df[
    (df["order_hour"] >= 10) & (df["order_hour"] < 14)
].shape[0]
plt.figure()
plt.bar(["Morning", "Late Morning"], [morning_orders, late_morning_orders])
plt.title("Morning vs Late-Morning Order Volume")
plt.xlabel("Time Period")
plt.ylabel("Number of Orders")
plt.show()

# %%
# Clean Total Price After Discount
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
city_revenue = df.groupby(
    "TO WHICH CITY WAS THE ORDER DELIVERED?"
)["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
top_3_cities = city_revenue.sort_values(ascending=False).head(3)
print("Top 3 cities with highest total revenue:")
print(top_3_cities)
# Out:
# Top 3 cities with highest total revenue:
# TO WHICH CITY WAS THE ORDER DELIVERED?
# DELHI      123620.0
# MUMBAI     104738.0
# KOLKATA     86511.0
# Name: WHAT IS THE TOTAL PRICE AFTER DISCOUNT?, dtype: float64

# %%
region_sales = df.groupby(
    "WHICH REGION DOES THE CITY BELONG TO?"
)["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
highest_region = region_sales.idxmax()
print("\nRegion generating highest sales:", highest_region)
print(region_sales)
# Out:
# Region generating highest sales: SOUTH
# WHICH REGION DOES THE CITY BELONG TO?
# CENTRAL     34246.0
# EAST       111876.0
# NORTH      111244.0
# SOUTH      127728.0
# WEST       103699.0
# Name: WHAT IS THE TOTAL PRICE AFTER DISCOUNT?, dtype: float64

# %%
category_discount = df.groupby(
    "WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"
)["WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?"].mean()
highest_discount_category = category_discount.idxmax()
print("\nCategory receiving highest average discount:", highest_discount_category)
print(category_discount)
# Out:
# Category receiving highest average discount: OTHERS
# WHICH CATEGORY DOES THIS PRODUCT BELONG TO?
# ACCESSORIES       13.500000
# BEAUTY            20.789474
# CLOTHING          32.100000
# ELECTRONICS       24.173913
# FOOTWEAR          19.333333
# HOME & KITCHEN    30.444444
# OTHERS            47.750000
# WEARABLES         18.750000
# Name: WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?, dtype: float64

# %%
electronics_revenue = df[
    df["WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"] == "ELECTRONICS"
]["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
non_electronics_revenue = df[
    df["WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"] != "ELECTRONICS"
]["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
print("\nElectronics Revenue:", electronics_revenue)
print("Non-Electronics Revenue:", non_electronics_revenue)
# Out:
# Electronics Revenue: 379404.0
# Non-Electronics Revenue: 109389.0

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
preferred_payment = df["WHAT PAYMENT METHOD WAS USED?"].value_counts().idxmax()
print("Most preferred payment method:", preferred_payment)
print(df["WHAT PAYMENT METHOD WAS USED?"].value_counts())
# Out:
# Most preferred payment method: UPI
# WHAT PAYMENT METHOD WAS USED?
# UPI            39
# DEBIT CARD     18
# COD            17
# CREDIT CARD    16
# NET BANKING    12
# Name: count, dtype: int64

# %%
cod_orders = df[df["WHAT PAYMENT METHOD WAS USED?"] == "COD"]
cod_status = cod_orders["WHAT IS THE CURRENT STATUS OF THE ORDER?"].value_counts()
print("\nCOD Order Status Distribution:")
print(cod_status)
# Out:
# COD Order Status Distribution:
# WHAT IS THE CURRENT STATUS OF THE ORDER?
# SHIPPED      7
# DELIVERED    5
# PENDING      5
# Name: count, dtype: int64

# %%
avg_order_value_payment = df.groupby(
    "WHAT PAYMENT METHOD WAS USED?"
)["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].mean()
print("\nAverage Order Value by Payment Method:")
print(avg_order_value_payment)
# Out:
# Average Order Value by Payment Method:
# WHAT PAYMENT METHOD WAS USED?
# COD              951.058824
# CREDIT CARD    16379.687500
# DEBIT CARD      2172.111111
# NET BANKING     3406.666667
# UPI             3348.000000
# Name: WHAT IS THE TOTAL PRICE AFTER DISCOUNT?, dtype: float64

# %%
customer_purchase = df.groupby(
    "ENTER YOUR NAME"
)["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"].sum()
top_customers = customer_purchase.sort_values(ascending=False).head(5)
print("\nTop customers with highest total purchase value:")
print(top_customers)
# Out:
# Top customers with highest total purchase value:
# ENTER YOUR NAME
# Sapna        61500.0
# Shambhavi    52500.0
# Priyanka     52000.0
# Zainab       49000.0
# Ahmed        40000.0
# Name: WHAT IS THE TOTAL PRICE AFTER DISCOUNT?, dtype: float64

# %%
import seaborn as sns
df["HOW MANY UNITS WERE PURCHASED?"] = df["HOW MANY UNITS WERE PURCHASED?"].replace(
    ["MORE THAN 4", "More than 4"], 5
)
df["HOW MANY UNITS WERE PURCHASED?"] = pd.to_numeric(
    df["HOW MANY UNITS WERE PURCHASED?"], errors="coerce"
)

# %%
df["WHAT IS THE PRICE PER UNIT? (IN RS)"] = (
    df["WHAT IS THE PRICE PER UNIT? (IN RS)"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE PRICE PER UNIT? (IN RS)"] = pd.to_numeric(
    df["WHAT IS THE PRICE PER UNIT? (IN RS)"], errors="coerce"
)

# %%
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = (
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"]
    .astype(str)
    .str.replace(",", "")
)
df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"] = pd.to_numeric(
    df["WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"], errors="coerce"
)

# %%
corr_data = df[
    [
        "HOW MANY UNITS WERE PURCHASED?",
        "WHAT IS THE PRICE PER UNIT? (IN RS)",
        "WHAT DISCOUNT PERCENTAGE WAS APPLIED (IF ANY)?",
        "WHAT IS THE TOTAL PRICE AFTER DISCOUNT?"
    ]
]
correlation_matrix = corr_data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
stacked_data = pd.crosstab(
    [df["WHICH CATEGORY DOES THIS PRODUCT BELONG TO?"],
     df["WHAT PAYMENT METHOD WAS USED?"]],
    df["WHAT IS THE CURRENT STATUS OF THE ORDER?"])
stacked_data.plot(
    kind="bar",
    stacked=True,
    figsize=(10,6))
plt.title("Category vs Payment Method vs Order Status")
plt.xlabel("Category & Payment Method")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45, ha="right")
plt.show()
